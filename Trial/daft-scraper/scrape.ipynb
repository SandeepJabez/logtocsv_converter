# %%
#scrape data from daft.ie website

# %%
import requests
from bs4 import BeautifulSoup

# Replace the URL with the one you want to scrape
url = 'https://www.daft.ie/for-rent/house-31-sandyford-hall-view-sandyford-dublin-18/4648115'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the response using Beautiful Soup
soup = BeautifulSoup(response.content, 'html.parser')

# Find an element in the HTML using its tag name and print its contents
# element = soup.find('h1')


# print(soup.prettify())
# get this part <script id="__NEXT_DATA__" type="application/json">
json_data=soup.find('script', id="__NEXT_DATA__").text
import json
#convert to doctionary
data = json.loads(json_data)
a=data['props']['pageProps']
a['listing']['seller']['phone']
# Out:
# '01 661 9670'

# %%
# Out:
# {'props': {'pageProps': {'daftCookies': {},
#    'listing': {'id': 4648115,
#     'title': '31 Sandyford Hall View, Sandyford, Dublin 18',
#     'seoTitle': '31 Sandyford Hall View, Sandyford, Sandyford, Dublin 18',
#     'sections': ['Property', 'Residential', 'House'],
#     'featuredLevel': 'PREMIUM',
#     'featuredLevelFull': 'PREMIUM',
#     'label': 'LET AGREED',
#     'lastUpdateDate': '24/03/2023',
#     'price': '€3,700 per month',
#     'numBedrooms': '4 Bed',
#     'numBathrooms': '3 Bath',
#     'propertyType': 'House',
#     'daftShortcode': '215484295',
#     'seller': {'sellerId': 8809,
#      'name': 'Gavin Donovan',
#      'phone': '01 661 9670',
#      'phoneWhenToCall': '9am - 5:30pm',
# ...

# %%
# data
# get phone
# Out:
# '01 661 9670'

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.daft.ie/for-rent/house-killeen-road-ranelagh-dublin-6/4646064'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract the heading
heading = soup.find('h1').text.strip()
print('Heading:', heading)

# Extract the contact number
contact_a = soup.find('a', {'class': 'NumberReveal__PhoneNumber-v2noxr-0 cLhApw'})
if contact_a:
    contact_number = contact_a.text.strip()
    print('Contact number:', contact_number)
else:
    print('Contact number not found')
# Out:
# Heading: Killeen Road, Ranelagh, Dublin 6
# Contact number: 01 456 4560
