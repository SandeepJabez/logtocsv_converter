# %%
#scrape data from daft.ie website

# %%
import requests
from bs4 import BeautifulSoup

# Replace the URL with the one you want to scrape
url = 'https://www.daft.ie/for-rent/house-31-sandyford-hall-view-sandyford-dublin-18/4648115'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the response using Beautiful Soup
soup = BeautifulSoup(response.content, 'html.parser')

# Find an element in the HTML using its tag name and print its contents
element = soup.find('h1')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1" name="viewport"/><meta content="IE" name="twitter:app:country"/><meta content="Daft.ie" name="twitter:app:name:iphone"/><meta content="346547065" name="twitter:app:id:iphone"/><meta content="https://apps.apple.com/ie/app/daft-ie/id346547065" name="twitter:app:url:iphone"/><meta content="Daft.ie" name="twitter:app:name:ipad"/><meta content="346547065" name="twitter:app:id:ipad"/><meta content="https://apps.apple.com/ie/app/daft-ie/id346547065" name="twitter:app:url:ipad"/><meta content="Daft - Buy, Rent or Share Ireland Real Estate" name="twitter:app:name:googleplay"/><meta content="com.daft.ie" name="twitter:app:id:googleplay"/><meta content="https://play.google.com/store/apps/details?id=com.daft.ie&amp;hl=en" name="twitter:app:url:googleplay"/><script src="https://www.google.com/recaptcha/enterprise.js?render=6LedZOIkAAAAAIbbno_VV2u9U3eI8BMTwvMAuj0K"></script><meta content="15702190222" property="fb:app_id"/><meta content="website" property="og:type"/><meta content="en_IE" property="og:locale"/><meta content="Daft" property="og:site_name"/><title>31 Sandyford Hall View, Sandyford, Dublin 18 is for rent on Daft.ie</title><meta content="index,follow" name="robots"/><meta content="index,follow" name="googlebot"/><meta content="31 Sandyford Hall View, Sandyford, Dublin 18 a 4 Bed House is now for rent by Gavin Donovan on Daft.ie with an asking price of €3,700 per month" name="description"/><meta content="summary_large_image" name="twitter:card"/><meta content="@daftmedia" name="twitter:creator"/><meta content="31 Sandyford Hall View, Sandyford, Dublin 18 is for rent on Daft.ie" property="og:title"/><meta content="31 Sandyford Hall View, Sandyford, Dublin 18 a 4 Bed House is now for rent by Gavin Donovan on Daft.ie with an asking price of €3,700 per month" property="og:description"/><meta content="https://www.daft.ie/for-rent/house-31-sandyford-hall-view-sandyford-dublin-18/4648115" property="og:url"/><meta content="https://media.daft.?signature=1587db2ff53e2392c8f0b2e9851efaf29c5ae5baaeca51241dface9b454e5284" property="og:image"/><meta content="31 Sandyford Hall View, Sandyford, Dublin 18 is for rent on Daft.ie" property="og:image:alt"/><meta content="1440" property="og:image:width"/><meta content="960" property="og:image:height"/><link href="https://www.daft.ie/for-rent/house-31-sandyford-hall-view-sandyford-dublin-18/4648115" rel="canonical"/><script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#       {
#         "@type": "ListItem",
#         "position": 1,
#         "item": {
#           "@id": "https://www.daft.ie/",
#           "name": "Home"
#         }
#       },{
#         "@type": "ListItem",
#         "position": 2,
#         "item": {
#           "@id": "https://www.daft.ie/property-for-rent/ireland",
#           "name": "Search Residential Property for Rent"
#         }
#       },{
#         "@type": "ListItem",
#         "position": 3,
#         "item": {
#           "@id": "https://www.daft.ie/property-for-rent/dublin/houses",
#           "name": "Dublin Houses for Rent"
#         }
#       },{
#         "@type": "ListItem",
#         "position": 4,
#         "item": {
#           "@id": "https://www.daft.ie/property-for-rent/sandyford-dublin/houses",
#           "name": "Sandyford Houses for Rent"
#         }
#       },{
#         "@type": "ListItem",
#         "position": 5,
#         "item": {
#           "@id": "https://www.daft.ie/for-rent/house-31-sandyford-hall-view-sandyford-dublin-18/4648115",
#           "name": "31 Sandyford Hall View, Sandyford, Sandyford, Dublin 18"
#         }
#       }
#      ]
#   }</script><meta content="32" name="next-head-count"/><script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-MHW55M7');
#       </script><script>
#         // Picture element HTML5 shiv
#         document.createElement( "picture" );
#       </script><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/favicon.ico" rel="icon"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="https://cookie-cutter.dsch.ie/1.3.0/cookieconsent.css" rel="stylesheet" type="text/css"/><meta content="#ffffff" name="msapplication-TileColor"/><meta content="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/ms-icon-144x144.png" name="msapplication-TileImage"/><meta content="#ffffff" name="theme-color"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="default" name="apple-mobile-web-app-status-bar-style"/><meta content="Daft.ie" name="apple-mobile-web-app-title"/><meta content="yes" name="mobile-web-app-capable"/><link href="/manifest.json" rel="manifest"/><link href="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/favicons/favicon.ico" rel="shortcut icon"/><link href="//hermes.daft.ie" rel="dns-prefetch"/><link href="//securepubads.g.doubleclick.net" rel="dns-prefetch"/><link href="//tag.aticdn.net" rel="dns-prefetch"/><link href="//static.hotjar.com" rel="dns-prefetch"/><link href="//cdn.wootric.com" rel="dns-prefetch"/><link href="//vars.hotjar.com" rel="dns-prefetch"/><link href="https://logs1154.xiti.com" rel="dns-prefetch"/><link href="//eligibility.wootric.com" rel="dns-prefetch"/><link href="//script.hotjar.com" rel="dns-prefetch"/><link href="//adservice.google.com" rel="dns-prefetch"/><link href="//adservice.google.ie" rel="dns-prefetch"/><link href="//www.google.analytics.com" rel="dns-prefetch"/><link href="//google.analytics.com" rel="dns-prefetch"/><link href="//googletagservices.com" rel="dns-prefetch"/><link href="//ad.doubleclick.net" rel="dns-prefetch"/><link href="//tcp.google.syndication.com" rel="dns-prefetch"/><link href="//www.google.analytics" rel="dns-prefetch"/><link href="//cdn.ampproject.org" rel="dns-prefetch"/><link href="//content.daft.ie" rel="dns-prefetch"/><link href="//googlesyndication.com" rel="dns-prefetch"/><link href="//dsch-content-hub-images-production.s3.eu-west-1.amazonaws.com" rel="dns-prefetch"/><lin ...
# *,*:before,*:after{box-sizing:inherit;}/*!sc*/
# body{margin:0;overflow-y:scroll;color:#333333;}/*!sc*/
# article,aside,footer,header,nav,section{display:block;}/*!sc*/
# h1{font-size:2em;margin:0.67em 0;}/*!sc*/
# figcaption,figure,main{display:block;}/*!sc*/
# figure{margin:1em 40px;}/*!sc*/
# hr{box-sizing:content-box;height:0;overflow:visible;}/*!sc*/
# pre{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# a{background-color:transparent;-webkit-text-decoration-skip:objects;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# abbr[title]{border-bottom:none;-webkit-text-decoration:underline;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted;}/*!sc*/
# b,strong{font-weight:inherit;}/*!sc*/
# b,strong{font-weight:bolder;}/*!sc*/
# code,kbd,samp{font-family:monospace,monospace;font-size:1em;}/*!sc*/
# dfn{font-style:italic;}/*!sc*/
# mark{background-color:#ff0;color:#000;}/*!sc*/
# small{font-size:80%;}/*!sc*/
# sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline;}/*!sc*/
# sub{bottom:-0.25em;}/*!sc*/
# sup{top:-0.5em;}/*!sc*/
# audio,video{display:inline-block;}/*!sc*/
# audio:not([controls]){display:none;height:0;}/*!sc*/
# img{border-style:none;}/*!sc*/
# svg:not(:root){overflow:hidden;}/*!sc*/
# button,input,optgroup,select,textarea{font-family:sans-serif;font-size:100%;line-height:1.15;margin:0;}/*!sc*/
# button,input{overflow:visible;}/*!sc*/
# button,select{text-transform:none;}/*!sc*/
# button,html [type='button'],[type='reset'],[type='submit']{-webkit-appearance:button;}/*!sc*/
# button{border:0;}/*!sc*/
# button::-moz-focus-inner,[type='button']::-moz-focus-inner,[type='reset']::-moz-focus-inner,[type='submit']::-moz-focus-inner{border-style:none;padding:0;}/*!sc*/
# button:-moz-focusring,[type='button']:-moz-focusring,[type='reset']:-moz-focusring,[type='submit']:-moz-focusring{outline:1px dotted ButtonText;}/*!sc*/
# fieldset{padding:0.35em 0.75em 0.625em;}/*!sc*/
# legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal;}/*!sc*/
# progress{display:inline-block;vertical-align:baseline;}/*!sc*/
# textarea{overflow:auto;}/*!sc*/
# [type='checkbox'],[type='radio']{box-sizing:border-box;padding:0;}/*!sc*/
# [type='number']::-webkit-inner-spin-button,[type='number']::-webkit-outer-spin-button{height:auto;}/*!sc*/
# [type='search']{-webkit-appearance:textfield;outline-offset:-2px;}/*!sc*/
# [type='search']::-webkit-search-cancel-button,[type='search']::-webkit-search-decoration{-webkit-appearance:none;}/*!sc*/
# ::-webkit-file-upload-button{-webkit-appearance:button;font:inherit;}/*!sc*/
# details,menu{display:block;}/*!sc*/
# summary{display:list-item;}/*!sc*/
# canvas{display:inline-block;}/*!sc*/
# template{display:none;}/*!sc*/
# [hidden]{display:none;}/*!sc*/
# *,*::before,*::after{box-sizing:inherit;}/*!sc*/
# ::selection{background:#333333;color:#ffffff;}/*!sc*/
# ::-moz-selection{background:#333333;color:#ffffff;}/*!sc*/
# body,h1,h2,h3,h4,h5,h6,p,blockquote,pre,dl,dd,ol,ul,form,fieldset,legend,figure,table,th,td,caption,hr{margin:0;padding:0;}/*!sc*/
# abbr[title],dfn[title]{cursor:help;}/*!sc*/
# img{display:inline-block;vertical-align:middle;max-width:100%;height:auto;}/*!sc*/
# ul,ol{list-style:none;margin:0;padding:0;}/*!sc*/
# button,input,optgroup,select,textarea,*{font-family:'Open Sans',sans-serif;}/*!sc*/
# .grecaptcha-badge{visibility:hidden;}/*!sc*/
# data-styled.g4[id="sc-global-gtGnKh1"]{content:"sc-global-gtGnKh1,"}/*!sc*/
# .fBczkN{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;white-space:nowrap;font-weight:600;border-radius:4px;height:20px;padding:0px 8px;background:#ffffff;font-size:10px;line-height:14px;color:#008940;border:1px solid #008940;}/*!sc*/
# @media only screen and (min-width:600px){.fBczkN{vertical-align:text-bottom;height:16px;padding:0px 4px;font-size:10px;line-height:14px;}}/*!sc*/
# data-styled.g8[id="Label__StyledSpan-sc-1vk68t4-0"]{content:"fBczkN,"}/*!sc*/
# @media only screen and (min-width:800px){.eDsjuA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g10[id="IconWithContentAndLabel__Wrapper-sc-1pv1vxd-0"]{content:"eDsjuA,"}/*!sc*/
# .kWzyZw{width:100%;}/*!sc*/
# .kWzyZw:not(:only-child){margin-bottom:12px;}/*!sc*/
# @media only screen and (min-width:800px){.kWzyZw:not(:only-child){margin-bottom:0;}}/*!sc*/
# data-styled.g11[id="IconWithContentAndLabel__IconWithContentWrapper-sc-1pv1vxd-1"]{content:"kWzyZw,"}/*!sc*/
# .eYmZIt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .eYmZIt > svg{min-width:20px;height:20px;margin:0 0 0 8px;-webkit-order:1;-ms-flex-order:1;order:1;}/*!sc*/
# @media only screen and (min-width:640px){.eYmZIt > svg{margin:0 0 0 8px;}}/*!sc*/
# data-styled.g12[id="IconWithContentAndLabel__StyledIconWithContent-sc-1pv1vxd-2"]{content:"eYmZIt,"}/*!sc*/
# .cIVIcD{overflow:hidden;text-overflow:ellipsis;white-space:nowrap;display:inline-block;}/*!sc*/
# @media only screen and (min-width:800px){.cIVIcD{display:inline-block;}}/*!sc*/
# data-styled.g16[id="NewButton__ButtonText-yem86a-0"]{content:"cIVIcD,"}/*!sc*/
# .cPAccb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .cPAccb svg{pointer-events:none;width:16px;height:16px;margin-right:8px;}/*!sc*/
# .cPAccb svg path{stroke-width:1.5px;}/*!sc*/
# @media only screen and (min-width:800px){.cPAccb svg{width:16px;height:16px;margin-right:8px;}}/*!sc*/
# @media only screen and (min-width:800px){.cPAccb svg{display:inline-block;}}/*!sc*/
# @media only screen and (min-width:800px){.cPAccb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# .gpUSsb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .gpUSsb svg{pointer-events:none;width:20px;height:20px;}/*!sc*/
# .gpUSsb svg path{stroke-width:1.5px;}/*!sc*/
# @media only screen and (min-width:800px){.gpUSsb svg{width:20px;height:20px;}}/*!sc*/
# @media only screen and (min-width:800px){.gpUSsb svg{display:inline-block;}}/*!sc*/
# @media only screen and (min-width:800px){.gpUSsb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# .izqXqe{display:none;}/*!sc*/
# .izqXqe svg{pointer-events:none;width:16px;height:16px;margin-right:8px;}/*!sc*/
# .izqXqe svg path{stroke-width:1.5px;}/*!sc*/
# @media only screen and (min-width:800px){.izqXqe svg{width:16px;height:16px;margin-right:8px;}}/*!sc*/
# @media only screen and (min-width:800px){.izqXqe svg{display:inline-block;}}/*!sc*/
# @media only screen and (min-width:800px){.izqXqe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}/*!sc*/
# data-styled.g17[id="NewButton__StyledIconToggleHolder-yem86a-1"]{content:"cPAccb,gpUSsb,izqXqe,"}/*!sc*/
# .bCXIix{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 10px;position:relative;padding:0;height:auto;line-height:18px;font-weight:400;color:#333333;text-transform:none;background-color:transparent;border:none;}/*!sc*/
# @media only screen and (min-width:800px){.bCXIix{height:65px;padding:0 22px;padding:0;height:auto;line-height:18px;}}/*!sc*/
# .bCXIix:hover{background-color:transparent;}/*!sc*/
# .bCXIix:disabled{cursor:unset;color:#bbbbbb;}/*!sc*/
# .klRAtd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 20px;position:relative;font-weight:700;color:#ffffff;text-transform:uppercase;background-color:#4170c4;border:none;}/*!sc*/
# @media only screen and (min-width:800px){.klRAtd{height:40px;padding:0 24px;}}/*!sc*/
# .klRAtd:hover{background-color:#30528f;}/*!sc*/
# .klRAtd:active{background-color:#638ace;border:none;}/*!sc*/
# .klRAtd:disabled{cursor:unset;background-color:#cbd8ee;}/*!sc*/
# .cWKcCS{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 20px;position:relative;font-weight:700;color:#ffffff;text-transform:uppercase;background-color:#4170c4;border:none;}/*!sc*/
# @media only screen and (min-width:800px){.cWKcCS{height:52px;padding:0 24px;}}/*!sc*/
# .cWKcCS:hover{background-color:#30528f;}/*!sc*/
# .cWKcCS:active{background-color:#638ace;border:none;}/*!sc*/
# .cWKcCS:disabled{cursor:unset;background-color:#cbd8ee;}/*!sc*/
# data-styled.g18[id="NewButton__StyledButton-yem86a-2"]{content:"bCXIix,klRAtd,cWKcCS,"}/*!sc*/
# .kqRZbP{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 20px;position:relative;padding:0;height:auto;line-height:18px;font-weight:400;color:#333333;text-transform:none;background-color:transparent;border:none;}/*!sc*/
# @media only screen and (min-width:800px){.kqRZbP{height:40px;padding:0 24px;padding:0;height:auto;line-height:18px;}}/*!sc*/
# .kqRZbP:hover{background-color:transparent;}/*!sc*/
# .kqRZbP:disabled{cursor:unset;color:#bbbbbb;}/*!sc*/
# .imQIKb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 20px;position:relative;font-weight:600;color:#333333;text-transform:none;background-color:#ffffff;border:1px solid #bbbbbb;}/*!sc*/
# @media only screen and (min-width:800px){.imQIKb{height:40px;padding:0 24px;}}/*!sc*/
# .imQIKb:hover{background-color:#ffffff;}/*!sc*/
# .imQIKb:disabled{cursor:unset;color:#bbbbbb;border:1px solid #dddddd;}/*!sc*/
# .jMayXA{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border-radius:4px;font-size:14px;cursor:pointer;width:100%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:40px;padding:0 20px;position:relative;font-weight:700;color:#4170c4;text-transform:uppercase;background-color:#ffffff;border:1px solid #4170c4;}/*!sc*/
# @media only screen and (min-width:800px){.jMayXA{height:40px;padding:0 24px;}}/*!sc*/
# .jMayXA:hover{background-color:#e0e8f6;color:#30528f;border:1px solid #30528f;}/*!sc*/
# .jMayXA:active{background-color:#f0f4fa;border:1px solid #30528f;}/*!sc*/
# .jMayXA:disabled{cursor:unset;background-color:#ffffff;color:#cbd8ee;border:1px solid #cbd8ee;}/*!sc*/
# data-styled.g19[id="NewButton__StyledButtonHrefLink-yem86a-3"]{content:"kqRZbP,imQIKb,jMayXA,"}/*!sc*/
# .hPYqbI{display:inline-block;}/*!sc*/
# .hPYqbI + .button-container:not(:first-of-type){margin-left:16px;}/*!sc*/
# @media only screen and (min-width:800px){.hPYqbI + .button-container:not(:first-of-type){margin-left:24px;}}/*!sc*/
# .deYANw{display:inline-block;width:100%;}/*!sc*/
# .deYANw + .button-container:not(:first-of-type){margin-left:16px;}/*!sc*/
# @media only screen and (min-width:800px){.deYANw + .button-container:not(:first-of-type){margin-left:24px;}}/*!sc*/
# data-styled.g20[id="NewButton__ButtonContainer-yem86a-4"]{content:"hPYqbI,deYANw,"}/*!sc*/
# .fJiQvL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# data-styled.g45[id="Breadcrumbs__Nav-sc-1j1uiln-0"]{content:"fJiQvL,"}/*!sc*/
# .RYGvQ{color:#000000;font-size:10px;font-weight:400;line-height:20px;}/*!sc*/
# @media only screen and (min-width:1024px){.RYGvQ{font-size:12px;line-height:14px;}}/*!sc*/
# .RYGvQ::after{content:'/';padding:0;margin:0 8px;}/*!sc*/
# data-styled.g46[id="Breadcrumbs__A-sc-1j1uiln-1"]{content:"RYGvQ,"}/*!sc*/
# .dhfuBQ{color:#000000;font-size:10px;font-weight:400;line-height:20px;}/*!sc*/
# @media only screen and (min-width:1024px){.dhfuBQ{font-size:12px;line-height:14px;}}/*!sc*/
# .dhfuBQ::after{content:'/';padding:0;margin:0 8px;}/*!sc*/
# .dhfuBQ:last-of-type{color:#bbbbbb;}/*!sc*/
# .dhfuBQ:last-of-type::after{display:none;}/*!sc*/
# data-styled.g47[id="Breadcrumbs__LastCrumb-sc-1j1uiln-2"]{content:"dhfuBQ,"}/*!sc*/
# .bddtwm{background:#ffffff;display:none;margin-top:auto;}/*!sc*/
# @media only screen and (min-width:1003px){.bddtwm{display:block;}}/*!sc*/
# data-styled.g48[id="Footer__Wrapper-sc-9uoo92-0"]{content:"bddtwm,"}/*!sc*/
# .dkmKyN{max-width:1040px;margin:0 auto;padding:12px;position:relative;}/*!sc*/
# .dkmKyN:after{content:' ';position:absolute;top:0;left:50%;height:1px;width:100vw;-webkit-transform:translate(-50%,-100%);-ms-transform:translate(-50%,-100%);transform:translate(-50%,-100%);background:#dddddd;}/*!sc*/
# @media only screen and (min-width:1038px){.dkmKyN{padding:22px 0;}}/*!sc*/
# data-styled.g49[id="Footer__BreadcrumbPanel-sc-9uoo92-1"]{content:"dkmKyN,"}/*!sc*/
# .eITviU{border-top:1px solid #dddddd;background-color:#ffffff;}/*!sc*/
# @media only screen and (min-width:1003px){.eITviU{padding-bottom:0;}}/*!sc*/
# data-styled.g50[id="Footer__FooterWrapper-sc-9uoo92-2"]{content:"eITviU,"}/*!sc*/
# .leQEKE{max-width:1040px;margin:0 auto;padding:34px 12px;}/*!sc*/
# @media only screen and (min-width:640px){.leQEKE{padding-top:40px;padding-bottom:40px;}}/*!sc*/
# @media only screen and (min-width:1038px){.leQEKE{padding-left:0px;padding-right:0px;}}/*!sc*/
# data-styled.g51[id="Footer__FooterContainer-sc-9uoo92-3"]{content:"leQEKE,"}/*!sc*/
# .cWyHId{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;list-style:none;}/*!sc*/
# @media only screen and (max-width:640px){.cWyHId{width:100%;}}/*!sc*/
# data-styled.g52[id="Footer__NavLinkContainer-sc-9uoo92-4"]{content:"cWyHId,"}/*!sc*/
# .eqoPfz{min-width:50%;padding-bottom:10px;cursor:pointer;}/*!sc*/
# @media only screen and (min-width:500px){.eqoPfz{min-width:33.3%;}}/*!sc*/
# @media only screen and (min-width:640px){.eqoPfz{min-width:25%;}}/*!sc*/
# @media only screen and (min-width:800px){.eqoPfz{-webkit-box-flex:0;-webkit-flex-grow:0;-ms-flex-positive:0;flex-grow:0;min-width:auto;margin-right:32px;padding-bottom:0;margin-bottom:14px;}}/*!sc*/
# data-styled.g53[id="Footer__NavLinkItem-sc-9uoo92-5"]{content:"eqoPfz,"}/*!sc*/
# .cJCIpQ{color:#333333;-webkit-text-decoration:none;text-decoration:none;font-size:12px;font-weight:600;}/*!sc*/
# .cJCIpQ:hover{border-bottom:2px solid #333333;}/*!sc*/
# data-styled.g54[id="Footer__NavLinkAnchor-sc-9uoo92-6"]{content:"cJCIpQ,"}/*!sc*/
# .jAolrd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;color:#717171;padding-top:22px;font-size:10px;}/*!sc*/
# @media only screen and (min-width:640px){.jAolrd{padding-top:16px;}}/*!sc*/
# data-styled.g55[id="Footer__InfoContainer-sc-9uoo92-7"]{content:"jAolrd,"}/*!sc*/
# .XkBkv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}/*!sc*/
# data-styled.g56[id="Footer__NavigationSection-sc-9uoo92-8"]{content:"XkBkv,"}/*!sc*/
# @media only screen and (min-width:800px){.grEMlt{font-size:12px;line-height:18px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:flex-start;-webkit-box-align:flex-start;-ms-flex-align:flex-start;align-items:flex-start;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;}}/*!sc*/
# data-styled.g60[id="FooterDefault__ContentContainer-ux0a23-0"]{content:"grEMlt,"}/*!sc*/
# .coNbwa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin-bottom:20px;}/*!sc*/
# @media only screen and (min-width:800px){.coNbwa{margin-bottom:0;}}/*!sc*/
# data-styled.g61[id="FooterDefault__LeftContent-ux0a23-1"]{content:"coNbwa,"}/*!sc*/
# .KkUBg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;font-size:12px;line-height:18px;}/*!sc*/
# data-styled.g62[id="FooterDefault__RightContent-ux0a23-2"]{content:"KkUBg,"}/*!sc*/
# .iWErOm{display:inline-block;padding-right:8px;}/*!sc*/
# .iWErOm svg{width:24px;height:24px;}/*!sc*/
# data-styled.g63[id="FooterDefault__LogoContainer-ux0a23-3"]{content:"iWErOm,"}/*!sc*/
# .jwoiUc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media only screen and (min-width:550px){.jwoiUc{font-size:12px;}}/*!sc*/
# data-styled.g64[id="FooterDefault__StringContainer-ux0a23-4"]{content:"jwoiUc,"}/*!sc*/
# .hpZCLh{margin-bottom:4px;}/*!sc*/
# .hpZCLh svg{width:158px;height:16px;color:#333333;}/*!sc*/
# @media only screen and (min-width:800px){.hpZCLh{margin-bottom:8px;margin-left:auto;}}/*!sc*/
# data-styled.g65[id="FooterDefault__DistilledFamilyIconContainer-ux0a23-5"]{content:"hpZCLh,"}/*!sc*/
# .ftAOhj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g66[id="FooterDefault__BrandsList-ux0a23-6"]{content:"ftAOhj,"}/*!sc*/
# .WODyF{color:#333333;font-weight:600;}/*!sc*/
# .WODyF:not(:first-of-type):before{content:'';width:4px;height:4px;border-radius:50%;display:inline-block;background-color:#bbbbbb;vertical-align:middle;margin:0 8px;}/*!sc*/
# data-styled.g67[id="FooterDefault__Brand-ux0a23-7"]{content:"WODyF,"}/*!sc*/
# .fORnpH{color:#333333;}/*!sc*/
# data-styled.g68[id="FooterDefault__StyledA-ux0a23-8"]{content:"fORnpH,"}/*!sc*/
# .rVCcE{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;padding:0;background:none;color:#333333;}/*!sc*/
# .rVCcE svg{width:24px;height:24px;}/*!sc*/
# data-styled.g69[id="Burger__BurgerContainer-cnr60u-0"]{content:"rVCcE,"}/*!sc*/
# .givumt{position:relative;color:#333333;border:none;outline:0;}/*!sc*/
# @media only screen and (min-width:900px){.givumt{display:none;}}/*!sc*/
# data-styled.g70[id="BurgerModal__StyledBurger-sc-18glq65-0"]{content:"givumt,"}/*!sc*/
# .kdIoQK__overlay{position:fixed;top:0px;left:0px;right:0px;bottom:0px;width:100%;z-index:9999;background-color:rgba(0,0,0,0.3);}/*!sc*/
# @media only screen and (min-width:900px){.kdIoQK__overlay{display:none;}}/*!sc*/
# .kdIoQK__content{outline:0;}/*!sc*/
# data-styled.g71[id="BurgerModal__StyledModal-sc-18glq65-1"]{content:"kdIoQK,"}/*!sc*/
# .cAmDkq{overflow:visible;display:block;color:#333333;}/*!sc*/
# @media only screen and (min-width:900px){.cAmDkq{cursor:pointer;display:none;z-index:100;position:absolute;}}/*!sc*/
# data-styled.g75[id="CollapsingItem__Content-ewem56-0"]{content:"cAmDkq,"}/*!sc*/
# .enCfmZ{position:relative;margin-bottom:22px;}/*!sc*/
# .enCfmZ:hover .CollapsingItem__Content-ewem56-0{display:block;}/*!sc*/
# @media only screen and (min-width:900px){.enCfmZ{margin-bottom:0;}}/*!sc*/
# data-styled.g76[id="CollapsingItem__Wrapper-ewem56-1"]{content:"enCfmZ,"}/*!sc*/
# .fPkEbt{width:100%;height:100%;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;color:inherit;}/*!sc*/
# data-styled.g77[id="CollapsingItem__ToggleOption-ewem56-2"]{content:"fPkEbt,"}/*!sc*/
# .gnDCwu{list-style-type:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media only screen and (min-width:900px){.gnDCwu{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g78[id="Navigationstyled__StyledNavigationList-sc-1tagpb7-0"]{content:"gnDCwu,"}/*!sc*/
# .dsbTRR{display:block;padding-left:48px;position:relative;font-weight:inherit;color:inherit;cursor:pointer;width:100%;height:100%;}/*!sc*/
# .dsbTRR.active{color:#4170c4;}/*!sc*/
# @media only screen and (min-width:900px){.dsbTRR{padding:0 24px;}}/*!sc*/
# data-styled.g79[id="Navigationstyled__StyledActiveLink-sc-1tagpb7-1"]{content:"dsbTRR,"}/*!sc*/
# .eZnXCo{display:block;line-height:34px;}/*!sc*/
# @media only screen and (min-width:900px){.eZnXCo{line-height:40px;}}/*!sc*/
# .eZnXCo:hover{background:#f4f4f4;}/*!sc*/
# .eZnXCo.active{color:#4170c4;}/*!sc*/
# @media only screen and (min-width:900px){.eZnXCo{margin-left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;}}/*!sc*/
# @media only screen and (min-width:900px){}/*!sc*/
# .glQlTl{display:block;line-height:34px;display:none;}/*!sc*/
# @media only screen and (min-width:900px){.glQlTl{line-height:40px;}}/*!sc*/
# .glQlTl:hover{background:#f4f4f4;}/*!sc*/
# .glQlTl.active{color:#4170c4;}/*!sc*/
# @media only screen and (min-width:900px){.glQlTl{margin-left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:center;-ms-flex-line-pack:center;align-content:center;}}/*!sc*/
# @media only screen and (min-width:900px){}/*!sc*/
# data-styled.g80[id="Navigationstyled__NavSubLinkListItem-sc-1tagpb7-2"]{content:"eZnXCo,glQlTl,"}/*!sc*/
# .kdwAeC{margin:0px 0 0px;}/*!sc*/
# @media only screen and (min-width:900px){.kdwAeC{postiion:relative;border:1px solid #dddddd;border-radius:4px;background-color:#ffffff;box-shadow:inset 0 0 16px 0 rgba(0,0,0,0.02);padding:17px 0px 17px;line-height:17px;width:259px;margin:12px 0 0 -26px;}}/*!sc*/
# .fBLlty{margin:0px 0 0px;}/*!sc*/
# @media only screen and (min-width:900px){.fBLlty{postiion:relative;border:1px solid #dddddd;border-radius:4px;background-color:#ffffff;box-shadow:inset 0 0 16px 0 rgba(0,0,0,0.02);padding:17px 0px 17px;line-height:17px;width:259px;margin:12px 0 0 -26px;position:relative;left:-166px;}}/*!sc*/
# data-styled.g81[id="Navigationstyled__NavSubLinkList-sc-1tagpb7-3"]{content:"kdwAeC,fBLlty,"}/*!sc*/
# .kydYkr{font-family:'Open Sans',sans-serif;background:transparent;display:inline;color:#333333;cursor:pointer;border:0;padding:0;position:relative;margin:0 33px 14px;font-weight:600;}/*!sc*/
# @media only screen and (min-width:900px){.kydYkr{font-weight:600;width:auto;margin:0 24px 0 0;text-align:inherit;}.kydYkr.active,.kydYkr:hover,.kydYkr:focus{outline:0;border:none;color:#4170c4;}.kydYkr.active:after,.kydYkr:hover:after,.kydYkr:focus:after{content:'';background-color:#4170c4;position:absolute;left:0px;display:block;height:3px;width:100%;bottom:-9px;}}/*!sc*/
# data-styled.g82[id="Navigationstyled__TopLevelItemActiveFakeButton-sc-1tagpb7-4"]{content:"kydYkr,"}/*!sc*/
# .bgdJHT{font-family:'Open Sans',sans-serif;background:transparent;display:inline;color:#333333;cursor:pointer;border:0;padding:0;position:relative;margin:0 33px 14px;font-weight:600;}/*!sc*/
# @media only screen and (min-width:900px){.bgdJHT{font-weight:600;width:auto;margin:0 24px 0 0;text-align:inherit;}.bgdJHT.active,.bgdJHT:hover,.bgdJHT:focus{outline:0;border:none;color:#4170c4;}.bgdJHT.active:after,.bgdJHT:hover:after,.bgdJHT:focus:after{content:'';background-color:#4170c4;position:absolute;left:0px;display:block;height:3px;width:100%;bottom:-9px;}}/*!sc*/
# .diZDlk{font-family:'Open Sans',sans-serif;background:transparent;display:inline;color:#333333;cursor:pointer;border:0;padding:0;position:relative;margin:0 33px 14px;margin-right:0;font-weight:600;}/*!sc*/
# @media only screen and (min-width:900px){.diZDlk{font-weight:600;width:auto;margin:0 24px 0 0;text-align:right;}.diZDlk.active,.diZDlk:hover,.diZDlk:focus{outline:0;border:none;color:#4170c4;}.diZDlk.active:after,.diZDlk:hover:after,.diZDlk:focus:after{content:'';background-color:#4170c4;position:absolute;left:0px;display:block;height:3px;width:100%;bottom:-9px;}}/*!sc*/
# data-styled.g83[id="Navigationstyled__TopLevelItemActiveButton-sc-1tagpb7-5"]{content:"bgdJHT,diZDlk,"}/*!sc*/
# .dGVmZq{font-family:'Open Sans',sans-serif;background:transparent;display:inline;color:#333333;cursor:pointer;border:0;padding:0;position:relative;margin:0 33px 14px;margin-right:0;}/*!sc*/
# .dGVmZq:visited{color:#333333;}/*!sc*/
# @media only screen and (min-width:900px){.dGVmZq{font-weight:600;width:auto;margin:0 24px 0 0;text-align:right;}.dGVmZq.active,.dGVmZq:hover,.dGVmZq:focus{outline:0;border:none;color:#4170c4;}.dGVmZq.active:after,.dGVmZq:hover:after,.dGVmZq:focus:after{content:'';background-color:#4170c4;position:absolute;left:0px;display:block;height:3px;width:100%;bottom:-9px;}}/*!sc*/
# data-styled.g84[id="Navigationstyled__TopLevelItemActiveLink-sc-1tagpb7-6"]{content:"dGVmZq,"}/*!sc*/
# .bfSnAZ{display:block;line-height:20px;font-size:14px;}/*!sc*/
# @media only screen and (min-width:900px){.bfSnAZ{font-size:14px;cursor:pointer;display:inline-block;}.bfSnAZ:hover .Navigationstyled__TopLevelItemActiveFakeButton-sc-1tagpb7-4,.bfSnAZ:hover .Navigationstyled__TopLevelItemActiveButton-sc-1tagpb7-5{color:#4170c4;}.bfSnAZ:hover .Navigationstyled__TopLevelItemActiveFakeButton-sc-1tagpb7-4:after,.bfSnAZ:hover .Navigationstyled__TopLevelItemActiveButton-sc-1tagpb7-5:after{content:'';background-color:#4170c4;position:absolute;left:0px;display:block;height:3px;width:100%;bottom:-9px;}.bfSnAZ:last-of-type .Navigationstyled__TopLevelItemActiveButton-sc-1tagpb7-5,.bfSnAZ:last-of-type .Navigationstyled__TopLevelItemActiveLink-sc-1tagpb7-6{margin:0;}}/*!sc*/
# data-styled.g85[id="Navigationstyled__StyledLI-sc-1tagpb7-7"]{content:"bfSnAZ,"}/*!sc*/
# .gFQLkT{position:absolute;top:-18px;right:-18px;}/*!sc*/
# data-styled.g86[id="Navigationstyled__LabelNewContainer-sc-1tagpb7-8"]{content:"gFQLkT,"}/*!sc*/
# .cgkweH{position:absolute;top:13px;right:32px;}/*!sc*/
# data-styled.g87[id="Navigationstyled__LabelNewSubItem-sc-1tagpb7-9"]{content:"cgkweH,"}/*!sc*/
# .hmcfGs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;height:auto;position:relative;z-index:600;background-color:#ffffff;max-height:56px;}/*!sc*/
# @media only screen and (min-width:900px){.hmcfGs{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# @media only screen and (min-width:900px){.hmcfGs{position:relative;max-height:70px;}}/*!sc*/
# data-styled.g88[id="Header__HeaderWrapper-w6uzdh-0"]{content:"hmcfGs,"}/*!sc*/
# .hOxQg{width:100%;height:auto;padding:16px;max-width:1040px;margin:0 auto;color:#333333;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media only screen and (min-width:720px){.hOxQg{padding:23px 16px;}}/*!sc*/
# @media only screen and (min-width:1040px){.hOxQg{padding:23px 0;}}/*!sc*/
# @media only screen and (min-width:900px){.hOxQg{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# data-styled.g89[id="Header__HeaderContent-w6uzdh-1"]{content:"hOxQg,"}/*!sc*/
# .eTpvHt{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;}/*!sc*/
# @media only screen and (min-width:900px){.eTpvHt{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# .eTpvHt > ul:first-of-type a{margin-left:0;}/*!sc*/
# @media only screen and (min-width:900px){.eTpvHt{display:none;}}/*!sc*/
# data-styled.g90[id="Header__MobileNavWrapper-w6uzdh-2"]{content:"eTpvHt,"}/*!sc*/
# .iblSrq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;display:none;}/*!sc*/
# @media only screen and (min-width:900px){.iblSrq{-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}}/*!sc*/
# @media only screen and (min-width:900px){.iblSrq{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-content:flex-end;-ms-flex-line-pack:end;align-content:flex-end;}.iblSrq >:last-child{margin-left:0px;}.iblSrq >:nth-child(2){margin-left:auto;}}/*!sc*/
# data-styled.g91[id="Header__DesktopNavWrapper-w6uzdh-3"]{content:"iblSrq,"}/*!sc*/
# .lgwOJy{height:20px;width:auto;display:block;}/*!sc*/
# @media only screen and (min-width:900px){.lgwOJy{height:25px;}}/*!sc*/
# data-styled.g92[id="Header__Logo-w6uzdh-4"]{content:"lgwOJy,"}/*!sc*/
# .kTuevd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#3a64ae;font-size:18px;font-weight:400;}/*!sc*/
# @media only screen and (min-width:900px){.kTuevd{margin-right:56px;}}/*!sc*/
# data-styled.g93[id="Header__LogoLink-w6uzdh-5"]{content:"kTuevd,"}/*!sc*/
# .hCEGjO{margin-right:14px;}/*!sc*/
# @media only screen and (min-width:900px){.hCEGjO:last-of-type{margin-right:0;}}/*!sc*/
# data-styled.g94[id="Header__NavHolder-w6uzdh-6"]{content:"hCEGjO,"}/*!sc*/
# .bZJvgL{min-height:calc(100vh - 56px);background:#ffffff;}/*!sc*/
# @media only screen and (min-width:900px){.bZJvgL{min-height:calc(100vh - 216px);}}/*!sc*/
# data-styled.g95[id="DefaultLayout__Main-sc-164pcf8-0"]{content:"bZJvgL,"}/*!sc*/
# .gTzBwO{cursor:pointer;position:relative;color:#333333;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:70px;background-color:#ffffff;position:relative;min-height:110px;padding:16px 8px 16px 0;box-shadow:0 4px 16px 0 rgba(51,51,51,0.16);}/*!sc*/
# data-styled.g281[id="SubUnit__Wrapper-sc-10x486s-0"]{content:"gTzBwO,"}/*!sc*/
# .kzlXlu{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}/*!sc*/
# @media only screen and (min-width:680px){.kzlXlu{padding-right:8px;}}/*!sc*/
# data-styled.g282[id="SubUnit__ColA-sc-10x486s-1"]{content:"kzlXlu,"}/*!sc*/
# .cIuOXb{margin:7px 0 7px 15px;height:50px;width:72px;background:#f4f4f4;}/*!sc*/
# @media only screen and (min-width:680px){.cIuOXb{margin:9px 0px 9px 24px;}}/*!sc*/
# data-styled.g283[id="SubUnit__ThumbnailBackdrop-sc-10x486s-2"]{content:"cIuOXb,"}/*!sc*/
# .eaTeUD{width:64px;height:56px;object-fit:cover;}/*!sc*/
# @media only screen and (min-width:680px){.eaTeUD{width:initial;height:initial;}}/*!sc*/
# data-styled.g284[id="SubUnit__Thumbnail-sc-10x486s-3"]{content:"eaTeUD,"}/*!sc*/
# .bIjqYp{padding-left:16px;}/*!sc*/
# data-styled.g285[id="SubUnit__StyledCol-sc-10x486s-4"]{content:"bIjqYp,"}/*!sc*/
# .feGTKf{font-size:14px;font-weight:600;line-height:20px;}/*!sc*/
# @media only screen and (min-width:680px){.feGTKf{font-size:14px;margin-bottom:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;}}/*!sc*/
# data-styled.g286[id="SubUnit__Title-sc-10x486s-5"]{content:"feGTKf,"}/*!sc*/
# .gCgIuC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;line-height:20px;}/*!sc*/
# @media only screen and (min-width:680px){.gCgIuC{margin-right:0;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;}}/*!sc*/
# data-styled.g287[id="SubUnit__CardInfo-sc-10x486s-6"]{content:"gCgIuC,"}/*!sc*/
# .kkrwvz{font-size:14px;color:#333333;padding-right:12px;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;max-height:40px;}/*!sc*/
# @media only screen and (min-width:680px){.kkrwvz{max-width:100%;white-space:normal;color:#333333;}}/*!sc*/
# .YYbRy{font-size:14px;color:#777777;padding-right:12px;overflow:hidden;text-overflow:ellipsis;display:-webkit-box;-webkit-line-clamp:2;-webkit-box-orient:vertical;max-width:24ch;white-space:nowrap;}/*!sc*/
# @media only screen and (min-width:680px){.YYbRy{max-width:100%;white-space:normal;color:#777777;}}/*!sc*/
# data-styled.g288[id="SubUnit__CardInfoItem-sc-10x486s-7"]{content:"kkrwvz,YYbRy,"}/*!sc*/
# .eamHZU{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media only screen and (min-width:800px){.eamHZU{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g290[id="SubUnit__CardInfoContainer-sc-10x486s-9"]{content:"eamHZU,"}/*!sc*/
# .gIjMDX{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g291[id="SubUnit__CardInfoWrapper-sc-10x486s-10"]{content:"gIjMDX,"}/*!sc*/
# .iZAQwx{line-height:22px;color:#4170c4;font-size:14px;white-space:nowrap;}/*!sc*/
# data-styled.g310[id="TitleBlock__CardExtraInfo-sc-1avkvav-3"]{content:"iZAQwx,"}/*!sc*/
# .kPVHUm{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#333333;font-size:16px;overflow:hidden;text-overflow:ellipsis;font-weight:600;margin-bottom:14px;line-height:1.4;}/*!sc*/
# @media only screen and (min-width:680px){.kPVHUm{font-size:20px;}}/*!sc*/
# data-styled.g311[id="TitleBlock__Price-sc-1avkvav-4"]{content:"kPVHUm,"}/*!sc*/
# .blbeVq{margin-right:12px;font-size:inherit;font-weight:600;}/*!sc*/
# data-styled.g312[id="TitleBlock__StyledCustomHeading-sc-1avkvav-5"]{content:"blbeVq,"}/*!sc*/
# .dzihxK{margin:0;color:#333333;font-size:14px;font-weight:600;margin-bottom:10px;overflow:hidden;position:relative;line-height:1.4;max-height:60px;}/*!sc*/
# @media only screen and (min-width:680px){.dzihxK{font-size:16px;margin-bottom:10px;}}/*!sc*/
# data-styled.g315[id="TitleBlock__Address-sc-1avkvav-8"]{content:"dzihxK,"}/*!sc*/
# .fgXVWJ{font-size:14px;color:#777777;padding-right:9px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media only screen and (min-width:680px){.fgXVWJ{font-size:16px;}}/*!sc*/
# .fgXVWJ:not(:first-of-type){position:relative;}/*!sc*/
# .fgXVWJ:not(:first-of-type):before{position:absolute;font-size:23px;content:'·';bottom:1px;color:#b6b6b6;display:block;left:-7px;}/*!sc*/
# .cKZYAr{font-size:14px;color:#777777;padding-right:9px;}/*!sc*/
# @media only screen and (min-width:680px){.cKZYAr{font-size:16px;}}/*!sc*/
# .cKZYAr:not(:first-of-type){position:relative;}/*!sc*/
# .cKZYAr:not(:first-of-type):before{position:absolute;font-size:23px;content:'·';bottom:1px;color:#b6b6b6;display:block;left:-7px;}/*!sc*/
# data-styled.g316[id="TitleBlock__CardInfoItem-sc-1avkvav-9"]{content:"fgXVWJ,cKZYAr,"}/*!sc*/
# .jJupQr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-top:-4px;line-height:22px;margin-right:30px;margin-bottom:4px;}/*!sc*/
# @media only screen and (min-width:680px){.jJupQr{margin-right:0;}}/*!sc*/
# .jJupQr p:nth-of-type(4){display:block;}/*!sc*/
# .jJupQr p:nth-of-type(4):before{display:block;}/*!sc*/
# data-styled.g317[id="TitleBlock__CardInfo-sc-1avkvav-10"]{content:"jJupQr,"}/*!sc*/
# .doPufQ{position:absolute;top:calc(50% - 20px);right:calc(50% - 20px);width:40px;height:40px;}/*!sc*/
# data-styled.g399[id="GenericForm__CenteredSpinner-sc-18lm415-0"]{content:"doPufQ,"}/*!sc*/
# .cILdyU{border:1px solid #dddddd;border-radius:4px;padding:24px;}/*!sc*/
# data-styled.g401[id="AllianzAdUnit__ContentWrapper-t4g7yl-0"]{content:"cILdyU,"}/*!sc*/
# .doSzMW{font-weight:600;font-size:16px;line-height:24px;color:#333333;}/*!sc*/
# data-styled.g402[id="AllianzAdUnit__Title-t4g7yl-1"]{content:"doSzMW,"}/*!sc*/
# .emyySx{font-size:14px;line-height:20px;color:#717171;margin-bottom:16px;}/*!sc*/
# data-styled.g403[id="AllianzAdUnit__Subtitle-t4g7yl-2"]{content:"emyySx,"}/*!sc*/
# .drqWPa{padding-left:4px;margin-bottom:16px;width:95px;height:24px;}/*!sc*/
# data-styled.g404[id="AllianzAdUnit__ImageContainer-t4g7yl-3"]{content:"drqWPa,"}/*!sc*/
# .hJPJmU{width:100%;padding:8px 10px;height:40px;background-color:#e84f23;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# @media only screen and (min-width:800px){.hJPJmU{height:52px;}}/*!sc*/
# data-styled.g405[id="AgentBranding__StyledAgentBranding-sc-1f8ugl2-0"]{content:"hJPJmU,"}/*!sc*/
# .jkquOQ img{max-height:32px;max-width:340px;}/*!sc*/
# @media only screen and (min-width:800px){.jkquOQ img{max-height:36px;max-width:240px;}}/*!sc*/
# data-styled.g406[id="AgentBranding__StyledLogo-sc-1f8ugl2-1"]{content:"jkquOQ,"}/*!sc*/
# .jFYvoa{max-width:1040px;margin:0 auto;padding-bottom:12px;}/*!sc*/
# ...
# .maKHo{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;margin-bottom:18px;}/*!sc*/
# data-styled.g563[id="styles__Container-sc-15uwzs5-7"]{content:"maKHo,"}/*!sc*/
# .fLxAAE{width:76px;-webkit-flex:0;-ms-flex:0;flex:0;-webkit-flex-basis:76px;-ms-flex-preferred-size:76px;flex-basis:76px;}/*!sc*/
# data-styled.g564[id="styles__Left-sc-15uwzs5-8"]{content:"fLxAAE,"}/*!sc*/
# .fJHxpr{-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;margin-left:16px;}/*!sc*/
# data-styled.g565[id="styles__Right-sc-15uwzs5-9"]{content:"fJHxpr,"}/*!sc*/
# .cvgZBj{color:#4170c4;cursor:pointer;margin-top:20px;font-size:14px;}/*!sc*/
# .cvgZBj:visited{color:#4170c4;}/*!sc*/
# data-styled.g566[id="styles__Anchor-sc-15uwzs5-10"]{content:"cvgZBj,"}/*!sc*/
# .oeukv{margin-bottom:6px;}/*!sc*/
# data-styled.g585[id="BerDetails__BerImage-sc-14a3wii-0"]{content:"oeukv,"}/*!sc*/
# .csoFAH{color:#333333;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-size:14px;line-height:24px;}/*!sc*/
# .csoFAH:first-of-type{margin-bottom:10px;}/*!sc*/
# @media only screen and (min-width:600px){.csoFAH{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;font-size:16px;}.csoFAH:first-of-type{margin-bottom:0;margin-right:94px;}}/*!sc*/
# data-styled.g597[id="Statistics__StyledStatsContainer-sc-15tgae4-0"]{content:"csoFAH,"}/*!sc*/
# .iDjRee{font-weight:600;}/*!sc*/
# data-styled.g598[id="Statistics__StyledLabel-sc-15tgae4-1"]{content:"iDjRee,"}/*!sc*/
# .MCfSO{font-weight:400;}/*!sc*/
# data-styled.g599[id="Statistics__StyledValue-sc-15tgae4-2"]{content:"MCfSO,"}/*!sc*/
# .hxVpqS{width:auto;}/*!sc*/
# .hxVpqS:first-of-type{width:88px;}/*!sc*/
# @media only screen and (min-width:600px){.hxVpqS:first-of-type{width:auto;margin-right:16px;}}/*!sc*/
# data-styled.g600[id="Statistics__StyledStat-sc-15tgae4-3"]{content:"hxVpqS,"}/*!sc*/
# @media only screen and (min-width:600px){.gNBtdx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;max-width:638px;}}/*!sc*/
# data-styled.g601[id="Statistics__MainContainer-sc-15tgae4-4"]{content:"gNBtdx,"}/*!sc*/
# .glbfmV{font-size:14px;line-height:19px;color:#999999;padding-top:40px;padding-bottom:20px;}/*!sc*/
# data-styled.g602[id="DaftIDText__StyledDaftIDParagraph-vbn7aa-0"]{content:"glbfmV,"}/*!sc*/
# .ftSJzy{list-style-type:disc;padding:0;margin-left:20px;font-size:14px;line-height:24px;list-style:default;color:#333333;}/*!sc*/
# @media only screen and (min-width:640px){.ftSJzy{font-size:16px;line-height:28px;}}/*!sc*/
# data-styled.g603[id="PropertyDetailsList__PropertyDetailsListContainer-sc-1cjwtjz-0"]{content:"ftSJzy,"}/*!sc*/
# .hqJwsU{padding:0;margin-bottom:20px;}/*!sc*/
# @media only screen and (min-width:640px){.hqJwsU{padding-left:10px;margin-bottom:28px;}}/*!sc*/
# .hqJwsU:last-of-type{margin-bottom:10px;}/*!sc*/
# data-styled.g604[id="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1"]{content:"hqJwsU,"}/*!sc*/
# </style><style data-href="https://fonts.googleapis.com/css?family=Open+Sans:400,600,700&amp;display=swap">@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsjZ0B4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsgH1x4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:700;font-stretch:normal;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memSYaGs126MiZpBA-UvWbX2vVnXBbObj2OVZyOOSr4dVJWUgsg-1x4gaVQ.woff) format('woff')}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSKmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSumu0SC55K5gw.woff2) format('woff2');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSOmu0SC55K5gw.woff2) format('woff2');unicode-range:U+1F00-1FFF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSymu0SC55K5gw.woff2) format('woff2');unicode-range:U+0370-03FF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTS2mu0SC55K5gw.woff2) format('woff2');unicode-range:U+0590-05FF,U+200C-2010,U+20AA,U+25CC,U+FB1D-FB4F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSCmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0102-0103,U+0110-0111,U+0128-0129,U+0168-0169,U+01A0-01A1,U+01AF-01B0,U+1EA0-1EF9,U+20AB}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSGmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0100-024F,U+0259,U+1E00-1EFF,U+2020,U+20A0-20AB,U+20AD-20CF,U+2113,U+2C60-2C7F,U+A720-A7FF}@font-face{font-family:'Open Sans';font-style:normal;font-weight:400;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTS-mu0SC55I.woff2) format('woff2');unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSKmu0SC55K5gw.woff2) format('woff2');unicode-range:U+0460-052F,U+1C80-1C88,U+20B4,U+2DE0-2DFF,U+A640-A69F,U+FE2E-FE2F}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic.com/s/opensans/v34/memvYaGs126MiZpBA-UvWbX2vVnXBbObj2OVTSumu0SC55K5gw.woff2) format('woff2');unicode-range:U+0301,U+0400-045F,U+0490-0491,U+04B0-04B1,U+2116}@font-face{font-family:'Open Sans';font-style:normal;font-weight:600;font-stretch:100%;font-display:swap;src:url(https://fonts.gstatic. ...
#       window.cookieConsentConfig = {
#         brand: 'daft',
#         cookieDomain: '.daft.ie',
#         privacyPolicy: 'https://support.daft.ie/hc/en-ie/articles/360003989197-Daft-Privacy-and-Cookie-Policies',
#         cookiePolicy: 'https://support.daft.ie/hc/en-ie/articles/360003989197-Daft-Privacy-and-Cookie-Policies#cookies',
#         version: '1.3.0',
#       };
#       </script><script src="https://cookie-cutter.dsch.ie/1.3.0/cookieconsent.js"></script><div data-reactroot="" id="__next"><script type="application/ld+json">{&quot;@context&quot;:&quot;https://schema.org&quot;,&quot;@type&quot;:&quot;Product&quot;,&quot;description&quot;:&quot;Bespoke Estate Agents are delighted to present this spacious 4 bed, 3 bath semi-detached house on Sandyford Hall View to the letting market. This house is located on quiet residential road with a host of amenities nearby. Sandyford Hall Park Shopping centre is just a 3 minute walk from the front door, which has a Centra, Costa Coffee, Pharmacy among other small shops. Sandyford Village is 1km away and Leopardstown Shopping Centre is 1.5km away. Public and private transport links are easily accessible with the Luas (Glencairn) just a 9 minute walk and bus routes close by. The M50 (Exit 14) is a 3 minute drive. Fernhill Park and Gardens are less than a 10 minute drive. \r\n\r\nThe house itself is fully furnished to a high standard and comes fully equipped with all the mod cons. There is a large 2 car front driveway as well as a spacious decked rear garden and side passage. Internally the house briefly comprises of an entrance hallway, downstairs WC, storage, large open plan kitchen and dining room, living room and rear conservatory. Upstairs there are 3 double bedrooms, en suite, a single bedroom and a modern main bathroom. \r\n\r\nViewing is highly recommended, please email any enquiries through the advert.&quot;,&quot;name&quot;:&quot;31 Sandyford Hall View, Sandyford, Sandyford, Dublin 18&quot;,&quot;image&quot;:&quot;https://media.daft.?signature=1587db2ff53e2392c8f0b2e9851efaf29c5ae5baaeca51241dface9b454e5284&quot;,&quot;offers&quot;:{&quot;@type&quot;:&quot;Offer&quot;,&quot;price&quot;:&quot;3700 per month&quot;,&quot;priceCurrency&quot;:&quot;EUR&quot;,&quot;availability&quot;:&quot;In Stock&quot;},&quot;countryOfOrigin&quot;:{&quot;@type&quot;:&quot;Country&quot;,&quot;name&quot;:&quot;IRL&quot;},&quot;productionDate&quot;:&quot;NA&quot;}</script><div class="styles__TopUnitWrapper-sc-15fxapi-21 jhZbN"></div><header class="Header__HeaderWrapper-w6uzdh-0 hmcfGs" data-testid="header-wrapper"><div class="Header__HeaderContent-w6uzdh-1 hOxQg"><a class="Header__LogoLink-w6uzdh-5 kTuevd" data-testid="logo-link" href="/"><img alt="Daft logo" class="Header__Logo-w6uzdh-4 lgwOJy" src="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/images/daft-logo.svg"/></a><div class="Header__MobileNavWrapper-w6uzdh-2 eTpvHt" data-testid="mobile-nav-wrapper"><button class="Burger__BurgerContainer-cnr60u-0 rVCcE BurgerModal__StyledBurger-sc-18glq65-0 givumt"><svg data-testid="burger-menu-open-button" height="1em" viewbox="0 0 24 24" width="1em"><g fill="none" fill-rule="evenodd" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round" stroke-width="2"><path d="M3 12h18M3 6h18M3 18h18"></path></g></svg></button></div><div class="Header__DesktopNavWrapper-w6uzdh-3 iblSrq" data-testid="desktop-nav-wrapper"><div class="Header__NavHolder-w6uzdh-6 hCEGjO"><ul class="Navigationstyled__StyledNavigationList-sc-1tagpb7-0 gnDCwu" data-testid="navigation"><li class="Navigationstyled__StyledLI-sc-1tagpb7-7 bfSnAZ" data-testid="nav-item-buy" display="block"><div class="CollapsingItem__Wrapper-ewem56-1 enCfmZ" data-testid="nav-menu"><div class="CollapsingItem__ToggleOption-ewem56-2 fPkEbt" data-testid="collapsable-content-toggle" role="button"><a aria-haspopup="true" class="Navigationstyled__TopLevelItemActiveFakeButton-sc-1tagpb7-4 kydYkr" data-testid="top-level-nav-item" href="/property ...
#
# The house itself is fully furnished to a high standard and comes fully equipped with all the mod cons. There is a large 2 car front driveway as well as a spacious decked rear garden and side passage. Internally the house briefly comprises of an entrance hallway, downstairs WC, storage, large open plan kitchen and dining room, living room and rear conservatory. Upstairs there are 3 double bedrooms, en suite, a single bedroom and a modern main bathroom.
#
# Viewing is highly recommended, please email any enquiries through the advert.</div></div><div class="styles__MapSection-sc-15fxapi-35 dxbhmt" data-testid="map-component"><h3 class="styles__H3-sc-15fxapi-6 styles__MapH3Mobile-sc-15fxapi-33 kOciVj fNAgrB">Map</h3><div class="styles__MapInfo-sc-15fxapi-36 jBMwfU"><h3 class="styles__H3-sc-15fxapi-6 styles__MapH3Desktop-sc-15fxapi-34 kOciVj lbvlPz">Map</h3><div class="styles__ButtonTray-sc-15fxapi-32 faqmlB"><div class="NewButton__ButtonContainer-yem86a-4 deYANw button-container"><a aria-label="Satellite View" class="NewButton__StyledButtonHrefLink-yem86a-3 imQIKb" data-testid="satelite-button" data-tracking="LaunchSatellite" href="https://www.google.com/maps?t=k&amp;q=loc:53.262445+-6.214705" rel="noreferrer noopener" target="_blank"><div class="NewButton__StyledIconToggleHolder-yem86a-1 izqXqe" data-testid=""><svg height="1em" viewbox="0 0 24 24" width="1em"><g fill="none" fill-rule="evenodd" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M21.5 12v7.917c0 .874-.71 1.583-1.583 1.583H4.083c-.874 0-1.583-.71-1.583-1.583V4.083c0-.874.71-1.583 1.583-1.583H12M15.5 2.5h6v6M10.5 13.5l11-11"></path></g></svg></div> <span class="NewButton__ButtonText-yem86a-0 cIVIcD">Satellite View</span></a></div><div class="NewButton__ButtonContainer-yem86a-4 deYANw button-container"><a aria-label="Street View" class="NewButton__StyledButtonHrefLink-yem86a-3 imQIKb" data-testid="streetview-button" data-tracking="LaunchStreet" href="https://www.google.com/maps/@?api=1&amp;map_action=pano&amp;viewpoint=53.262445,-6.214705" rel="noreferrer noopener" target="_blank"><div class="NewButton__StyledIconToggleHolder-yem86a-1 izqXqe" data-testid=""><svg height="1em" viewbox="0 0 24 24" width="1em"><g fill="none" fill-rule="evenodd" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M21.5 12v7.917c0 .874-.71 1.583-1.583 1.583H4.083c-.874 0-1.583-.71-1.583-1.583V4.083c0-.874.71-1.583 1.583-1.583H12M15.5 2.5h6v6M10.5 13.5l11-11"></path></g></svg></div> <span class="NewButton__ButtonText-yem86a-0 cIVIcD">Street View</span></a></div></div></div></div></div><div class="styles__ContentPadding-sc-15fxapi-4 cwTbNv"><div class="styles__ContentSection-sc-15fxapi-3 kbrydT" data-testid="facilities"><h3 class="styles__H3-sc-15fxapi-6 kOciVj">Property Facilities</h3><ul class="PropertyDetailsList__PropertyDetailsListContainer-sc-1cjwtjz-0 ftSJzy"><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Parking</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Central Heating</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Alarm</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Cable Television</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Washing Machine</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Dryer</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Dishwasher</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Microwave</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Pets Allowed</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Internet</li><li class="PropertyDetailsList__PropertyDetailsListItem-sc-1cjwtjz-1 hqJwsU">Garden / Patio / Balcony</li></ul></div><div class="styles__ContentSection-sc-15fxapi-3 kbrydT" data-testid="ber"><h3 class="styles__H3-sc-15fxapi-6 kOciVj">BER Details</h3><img alt="E1" class="BerDetails__BerImage-sc-14a3wii-0 oeukv" src="https://hermes.daft.ie/dsch-daft-frontend/1.0.1679415320/static/images/ber/E1.svg"/><div class="styles__BerDFPWrapper-sc-15fxapi-44 hzgIxA"></div></div><div class="styles__ContentSection-sc-15fxapi-3 kbrydT" data-testid="statistics"><h3 class="styles__H3-sc-15fxapi-6 kOciVj">Statistics</h3><div class="Statistics__M ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.daft.ie/for-rent/house-killeen-road-ranelagh-dublin-6/4646064'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Extract the heading
heading = soup.find('h1').text.strip()
print('Heading:', heading)

# Extract the contact number
contact_a = soup.find('a', {'class': 'NumberReveal__PhoneNumber-v2noxr-0 cLhApw'})
if contact_a:
    contact_number = contact_a.text.strip()
    print('Contact number:', contact_number)
else:
    print('Contact number not found')
# Out:
# Heading: Killeen Road, Ranelagh, Dublin 6
# Contact number: 01 456 4560
