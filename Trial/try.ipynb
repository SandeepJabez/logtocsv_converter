# %%
import csv

def convert_to_csv(input_file, output_file):
    with open(input_file, 'r') as f_input, open(output_file, 'w', newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        for line in f_input:
            data=[]
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            csv_writer.writerow(data)
            # fields = line.strip().split("   ")
            # csv_writer.writerow(fields)

input_file = "/home/dev/Desktop/Trial/access.log"
output_file = "log_file.csv"
convert_to_csv(input_file, output_file)

# %%
import csv
import os

def convert_to_csv(input_file, output_file):
    header_written = False 

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            csv_writer.writerow(data)

input_file = "/home/dev/Desktop/Trial/access.log"
output_file = "log_file2.csv"
convert_to_csv(input_file, output_file)

# %%
#code to check if there are duplicate entries in the csv file

def check_duplicate(input_file):
    with open(input_file, 'r') as f_input:
        csv_reader = csv.reader(f_input, delimiter=',')
        next(csv_reader)
        for row in csv_reader:
            print(row)

# %%
#293965

# %%
import csv
import os

def convert_to_csv(input_file, output_file, last_row_file):
    header_written = False 
    last_row = ""

    if os.path.exists(last_row_file):
        with open(last_row_file, 'r') as last_row_input:
            last_row = last_row_input.read().strip()

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            line = line.strip()
            if line != last_row:
                data = []
                for item in line.split(" "):
                    if item != "":
                        data.append(item)
                csv_writer.writerow(data)
                last_row = line

    with open(last_row_file, 'w') as last_row_output:
        last_row_output.write(last_row)

input_file = "/home/dev/Desktop/Trial/access.log"
output_file = "log_file2.csv"
last_row_file = "last_row.txt"
convert_to_csv(input_file, output_file, last_row_file)

# %%
# 28265

# %%
import csv

processed_data = set()

def convert_to_csv(input_file, output_file):
    with open(input_file, 'r') as f_input, open(output_file, 'a', newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            data_str = ",".join(data)
            if data_str not in processed_data:
                csv_writer.writerow(data)
                processed_data.add(data_str)

input_file = "/home/dev/Desktop/Trial/access.log"
output_file = "log_file.csv"
convert_to_csv(input_file, output_file)

# %%
# 554512

# %%
import csv
import os

def convert_to_csv(input_file, output_file):
    header_written = False 
    processed_records = set()

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True

        # Load the processed records from the CSV file
        with open(output_file, 'r') as f_output:
            csv_reader = csv.reader(f_output)
            next(csv_reader)  # skip the header row
            processed_records = set(row for row in csv_reader)
    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            record = tuple(data)
            if record not in processed_records:
                csv_writer.writerow(record)
                processed_records.add(record)

input_file = "/home/dev/Desktop/Trial/access.log"
output_file = "log_file2.csv"
convert_to_csv(input_file, output_file)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 39
#      37 input_file = "/home/dev/Desktop/Trial/access.log"
#      38 output_file = "log_file2.csv"
# ---> 39 convert_to_csv(input_file, output_file)
#
# Cell In[9], line 16, in convert_to_csv(input_file, output_file)
#      14         csv_reader = csv.reader(f_output)
#      15         next(csv_reader)  # skip the header row
# ---> 16         processed_records = set(row for row in csv_reader)
#      17 else:
#      18     mode = 'w' # write if file does not exist
#
# TypeError: unhashable type: 'list'

# %%
#554512

# %%
import csv
import os
import hashlib

def hash_row(row):
    return hashlib.sha1(str(row).encode()).hexdigest()

def convert_to_csv(input_file, output_file):
    header_written = False 
    processed_rows = set()

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
        
        with open(output_file, 'r') as f:
            reader = csv.reader(f)
            for row in reader:
                processed_rows.add(hash_row(row))

    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            row_hash = hash_row(data) 
            if row_hash not in processed_rows:
                csv_writer.writerow(data)
                processed_rows.add(row_hash)

input_file = 
output_file = 
convert_to_csv(input_file, output_file)

# %%
# 554513

# %% [markdown]
# # For single file upload

# %%
import csv
import os
import tkinter as tk
from tkinter import filedialog

def convert_to_csv(input_file, output_file):
    header_written = False
    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            csv_writer.writerow(data)

def browse_input_file():
    filename = filedialog.askopenfilename(filetypes=[('Log files', '*.log')])
    input_file_entry.delete(0, tk.END)
    input_file_entry.insert(0, filename)

def browse_output_file():
    filename = filedialog.asksaveasfilename(defaultextension='.csv')
    output_file_entry.delete(0, tk.END)
    output_file_entry.insert(0, filename)

def convert():
    input_file = input_file_entry.get()
    output_file = output_file_entry.get()
    convert_to_csv(input_file, output_file)
    status_label.config(text='Conversion complete!')

# Create the main window
window = tk.Tk()
window.title('Log File Converter')

# Create the input file section
input_frame = tk.Frame(window)
input_label = tk.Label(input_frame, text='Input file:')
input_label.pack(side=tk.LEFT)
input_file_entry = tk.Entry(input_frame)
input_file_entry.pack(side=tk.LEFT, fill=tk.X, expand=True)
input_browse_button = tk.Button(input_frame, text='Browse', command=browse_input_file)
input_browse_button.pack(side=tk.LEFT)
input_frame.pack(fill=tk.X, padx=10, pady=10)

# Create the output file section
output_frame = tk.Frame(window)
output_label = tk.Label(output_frame, text='Output file:')
output_label.pack(side=tk.LEFT)
output_file_entry = tk.Entry(output_frame)
output_file_entry.pack(side=tk.LEFT, fill=tk.X, expand=True)
output_browse_button = tk.Button(output_frame, text='Browse', command=browse_output_file)
output_browse_button.pack(side=tk.LEFT)
output_frame.pack(fill=tk.X, padx=10, pady=10)

# Create the convert button
convert_button = tk.Button(window, text='Convert', command=convert)
convert_button.pack(padx=10, pady=10)

# Create the status label
status_label = tk.Label(window, text='')
status_label.pack(padx=10, pady=10)

# Run the main loop
window.mainloop()

# %% [markdown]
# # For multiple file upload

# %%
import csv
import os
import tkinter as tk
from tkinter import filedialog

def convert_to_csv(input_file, output_file):
    header_written = False 

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
    else:
        mode = 'w' # write if file does not exist

    with open(input_file, 'r') as f_input, open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for line in f_input:
            data = []
            for item in line.split(" "):
                if item != "":
                    data.append(item)
            csv_writer.writerow(data)

def convert_files():
    # Open file dialog to select input files
    root = tk.Tk()
    root.withdraw()
    file_paths = filedialog.askopenfilenames()

    # Convert each input file to CSV
    for file_path in file_paths:
        output_file = os.path.splitext(file_path)[0] + ".csv"
        convert_to_csv(file_path, output_file)

    # Show message box on completion
    tk.messagebox.showinfo("Conversion Complete", "All selected files have been converted to CSV.")

# Create a tkinter GUI window
window = tk.Tk()
window.title("Log File Converter")

# Create a button to initiate file conversion
button = tk.Button(window, text="Select Files to Convert", command=convert_files)
button.pack(pady=20)

# Start the GUI loop
window.mainloop()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 52
#      49 button.pack(pady=20)
#      51 # Start the GUI loop
# ---> 52 window.mainloop()
#
# File /usr/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %% [markdown]
# # Modified for multiple file upload with option of output file

# %%
import csv
import os
import tkinter as tk
from tkinter import filedialog

def convert_to_csv(input_files, output_file):
    header_written = False
    last_record = None

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True
    else:
        mode = 'w' # write if file does not exist

    with open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
            header_written = True

        for input_file in input_files:
            with open(input_file, 'r') as f_input:
                for line in f_input:
                    data = []
                    for item in line.split(" "):
                        if item != "":
                            data.append(item)
                    if data != last_record:
                        csv_writer.writerow(data)
                    last_record = data

def choose_input_files():
    input_files = filedialog.askopenfilenames(title="Choose Log Files")
    input_var.set(input_files)

def choose_output_file():
    output_file = filedialog.asksaveasfilename(title="Choose Output File", defaultextension=".csv")
    output_var.set(output_file)

# create the GUI
root = tk.Tk()
root.title("Log File Converter")

# create the input file label and button
input_label = tk.Label(root, text="Input Files:")
input_label.grid(row=0, column=0)

input_var = tk.StringVar()
input_entry = tk.Entry(root, textvariable=input_var)
input_entry.grid(row=0, column=1)

input_button = tk.Button(root, text="Choose Files", command=choose_input_files)
input_button.grid(row=0, column=2)

# create the output file label and button
output_label = tk.Label(root, text="Output File:")
output_label.grid(row=1, column=0)

output_var = tk.StringVar()
output_entry = tk.Entry(root, textvariable=output_var)
output_entry.grid(row=1, column=1)

output_button = tk.Button(root, text="Choose File", command=choose_output_file)
output_button.grid(row=1, column=2)

# create the convert button
convert_button = tk.Button(root, text="Convert", command=lambda: convert_to_csv(input_var.get().split(","), output_var.get()))
convert_button.grid(row=2, column=1)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/tmp/ipykernel_26208/1814189110.py", line 69, in <lambda>
#     convert_button = tk.Button(root, text="Convert", command=lambda: convert_to_csv(input_var.get().split(","), output_var.get()))
#   File "/tmp/ipykernel_26208/1814189110.py", line 24, in convert_to_csv
#     with open(input_file, 'r') as f_input:
#   File "/home/dev/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 282, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: "('/home/dev/Desktop/Trial/access copy.log'"
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
# ...

# %% [markdown]
# # With exit option

# %%
import csv
import os
import tkinter as tk
from tkinter import filedialog

def convert_to_csv(input_files, output_file):
    header_written = False
    last_record = None

    if os.path.exists(output_file):
        mode = 'a' # append if file exists
        header_written = True

        # Read the last record from the existing CSV file
        with open(output_file, 'r') as f:
            reader = csv.reader(f)
            for row in reader:
                last_record = row

    else:
        mode = 'w' # write if file does not exist

    with open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp", "timezone", "request size", "source ip", "cache status", "status code", "request method", "url", "empty", "hierarchy destination ip", "mime"])
            header_written = True

        for input_file in input_files:
            with open(input_file, 'r') as f_input:
                for line in f_input:
                    data = []
                    for item in line.split(" "):
                        if item != "":
                            data.append(item)

                    # Check if the current record is the same as the last record in the CSV file
                    if last_record and last_record == data:
                        continue  # Skip this record

                    csv_writer.writerow(data)
                    last_record = data

def choose_input_files():
    filetypes = (("Log files", "*.log"), ("All files", "*.*"))
    return filedialog.askopenfilenames(filetypes=filetypes)

def choose_output_file():
    filetypes = (("CSV files", "*.csv"), ("All files", "*.*"))
    return filedialog.asksaveasfilename(defaultextension=".csv", filetypes=filetypes)

def on_convert_button_click():
    input_files = choose_input_files()
    if not input_files:
        return  # User clicked Cancel

    output_file = choose_output_file()
    if not output_file:
        return  # User clicked Cancel

    convert_to_csv(input_files, output_file)
    tk.messagebox.showinfo("Conversion Complete", "Log files have been converted to CSV.")

root = tk.Tk()
root.title("Log to CSV Converter")

convert_button = tk.Button(root, text="Convert", command=on_convert_button_click)
convert_button.pack(pady=10)

exit_button = tk.Button(root, text="Exit", command=root.quit)
exit_button.pack()

root.mainloop()

# %% [markdown]
# #exit with updation

# %%
import tkinter as tk
from tkinter import filedialog
import csv
import os

def convert_to_csv(input_files, output_file):
    header_written = False
    output_file_exists = os.path.exists(output_file)

    if output_file_exists:
        mode = 'a'
        header_written = True
    else:
        mode = 'w'

    with open(output_file, mode, newline='') as f_output:
        csv_writer = csv.writer(f_output, delimiter=',')

        if not header_written:
            csv_writer.writerow(["timestamp", "timezone", "request size", "source ip", "cache status", "status code", "request method", "url", "empty", "hierarchy destination ip", "mime"])
            header_written = True

        for input_file in input_files:
            with open(input_file, 'r') as f_input:
                for line in f_input:
                    data = []
                    for item in line.split(" "):
                        if item != "":
                            data.append(item)
                    csv_writer.writerow(data)

def browse_files():
    files = filedialog.askopenfilenames(filetypes=[("Log Files", "*.log")])
    input_files_entry.delete(0, tk.END)
    input_files_entry.insert(0, files)

def browse_output_file():
    file = filedialog.asksaveasfilename(defaultextension=".csv", filetypes=[("CSV Files", "*.csv")])
    output_file_entry.delete(0, tk.END)
    output_file_entry.insert(0, file)

def convert_and_exit():
    input_files = input_files_entry.get().split()
    output_file = output_file_entry.get()
    convert_to_csv(input_files, output_file)
    root.destroy()

root = tk.Tk()
root.title("Log File Converter")

input_files_label = tk.Label(root, text="Input Files:")
input_files_entry = tk.Entry(root, width=50)
input_files_button = tk.Button(root, text="Browse", command=browse_files)

output_file_label = tk.Label(root, text="Output File:")
output_file_entry = tk.Entry(root, width=50)
output_file_button = tk.Button(root, text="Browse", command=browse_output_file)

convert_button = tk.Button(root, text="Convert", command=convert_and_exit)
exit_button = tk.Button(root, text="Exit", command=root.destroy)

input_files_label.grid(row=0, column=0, padx=5, pady=5, sticky="w")
input_files_entry.grid(row=0, column=1, padx=5, pady=5)
input_files_button.grid(row=0, column=2, padx=5, pady=5)

output_file_label.grid(row=1, column=0, padx=5, pady=5, sticky="w")
output_file_entry.grid(row=1, column=1, padx=5, pady=5)
output_file_button.grid(row=1, column=2, padx=5, pady=5)

convert_button.grid(row=2, column=1, padx=5, pady=5)
exit_button.grid(row=2, column=2, padx=5, pady=5)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/tmp/ipykernel_26208/2821794917.py", line 45, in convert_and_exit
#     convert_to_csv(input_files, output_file)
#   File "/tmp/ipykernel_26208/2821794917.py", line 24, in convert_to_csv
#     with open(input_file, 'r') as f_input:
#   File "/home/dev/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 282, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '{/home/dev/Desktop/Trial/access'

# %% [markdown]
# # Finalised Version

# %%
import csv
import os
import hashlib
import tkinter as tk
from tkinter import filedialog, messagebox


class Application(tk.Frame):
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.create_widgets()

    def create_widgets(self):
        # Add input file button
        self.input_files = []
        self.add_input_button = tk.Button(self, text="Add input file", command=self.add_input)
        self.add_input_button.pack(side="top")

        # Add output file button
        self.output_file = None
        self.add_output_button = tk.Button(self, text="Choose output file", command=self.choose_output)
        self.add_output_button.pack(side="top")

        # Convert button
        self.convert_button = tk.Button(self, text="Convert", command=self.convert)
        self.convert_button.pack(side="top")

        # Exit button
        self.quit = tk.Button(self, text="Exit", fg="red", command=self.master.destroy)
        self.quit.pack(side="bottom")

    def add_input(self):
        # Add one or more input files
        filepaths = filedialog.askopenfilenames(title="Select input file", filetypes=[("Log files", "*.log")])
        self.input_files.extend(filepaths)

    def choose_output(self):
        # Choose output file
        filepath = filedialog.asksaveasfilename(title="Save as", defaultextension=".csv", filetypes=[("CSV files", "*.csv")])
        self.output_file = filepath

    def convert(self):
        if not self.input_files:
            messagebox.showerror("Error", "No input files selected.")
            return
        if not self.output_file:
            messagebox.showerror("Error", "No output file selected.")
            return

        # Convert all input files
        header_written = False
        temp_file = "temp.txt"
        saved_hash = ""

        with open(self.output_file, 'a', newline='') as f_output:
            csv_writer = csv.writer(f_output, delimiter=',')

            for input_file in self.input_files:
                with open(input_file, 'r') as f_input:
                    for line in f_input:
                        data = []
                        for item in line.split(" "):
                            if item != "":
                                data.append(item)

                        # Check if data is already in the CSV
                        current_hash = hashlib.md5(str(data).encode('utf-8')).hexdigest()
                        if current_hash == saved_hash:
                            continue

                        saved_hash = current_hash

                        # Write header if not already written
                        if not header_written:
                            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])
                            header_written = True

                        # Write data to CSV
                        csv_writer.writerow(data)

        # Write saved hash to temp file
        with open(temp_file, "w") as f:
            f.write(saved_hash)

        messagebox.showinfo("Success", "Conversion complete.")


root = tk.Tk()
root.title("Log Converter")
app = Application(master=root)
app.mainloop()

# %% [markdown]
# Trying different one as they overwrote

# %%
import csv
import os
import hashlib
import tempfile
import tkinter as tk
from tkinter import filedialog

# Create a temporary file for storing the processed rows set
temp_file = tempfile.NamedTemporaryFile(mode='w+t', delete=False)
processed_rows = set()

def hash_row(row):
    return hashlib.sha1(str(row).encode()).hexdigest()

def convert_and_append():
    input_files = filedialog.askopenfilenames(title="Select Log Files", filetypes=(("Log Files", "*.log"),))
    output_file = filedialog.asksaveasfilename(title="Save as CSV", defaultextension=".csv", filetypes=(("CSV Files", "*.csv"),))

    if not output_file:
        return

    if os.path.exists(output_file):
        mode = 'a' # append if file exists

        with open(output_file, 'r') as f:
            reader = csv.reader(f)
            for row in reader:
                processed_rows.add(hash_row(row))

    else:
        mode = 'w' # write if file does not exist

    with open(output_file, mode, newline='') as f_output, open(temp_file.name, 'r+') as f_processed_rows:
        csv_writer = csv.writer(f_output, delimiter=',')

        if mode == 'w':
            csv_writer.writerow(["timestamp","timezone", "request size", "source ip", "cache status", "status code", "request method", "url","empty", "hierarchy destination ip", "mime"])

        f_processed_rows.seek(0)
        processed_rows.update(set(f_processed_rows.read().splitlines()))

        for input_file in input_files:
            with open(input_file, 'r') as f_input:
                for line in f_input:
                    data = []
                    for item in line.split(" "):
                        if item != "":
                            data.append(item)
                    row_hash = hash_row(data) 
                    if row_hash not in processed_rows:
                        csv_writer.writerow(data)
                        processed_rows.add(row_hash)

        f_processed_rows.seek(0)
        f_processed_rows.write('\n'.join(processed_rows))
        f_processed_rows.truncate()

    print("Conversion complete.")

def exit_application():
    root.destroy()
    temp_file.close()
    os.unlink(temp_file.name)

root = tk.Tk()
root.title("Log Converter")

frame = tk.Frame(root)
frame.pack(padx=10, pady=10)

tk.Button(frame, text="Convert and Append", command=convert_and_append).grid(row=0, column=0, padx=5, pady=5)
tk.Button(frame, text="Exit", command=exit_application).grid(row=0, column=1, padx=5, pady=5)

root.mainloop()
# Out:
# Conversion complete.
# Conversion complete.
